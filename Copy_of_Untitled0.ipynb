# %%
from bs4 import BeautifulSoup
import requests
import urllib.request

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Ralph_Lauren_Retail_Feed.csv')
print(df.shape)
df.head()
# Out:
# (41652, 47)
#        pmg_brand pmg_region  ... suppressed         last_updated
# 0  ralph lauren          us  ...      False  2021-05-28 13:55:38
# 1  ralph lauren          us  ...      False  2021-05-28 13:57:15
# 2  ralph lauren          us  ...      False  2021-05-28 13:58:08
# 3  ralph lauren          us  ...      False  2021-05-28 13:59:45
# 4  ralph lauren          us  ...      False  2021-05-28 13:59:32
#
# [5 rows x 47 columns]

# %%
for i in range(len(df)):
  html_page = requests.get(df['url'][i])
  soup = BeautifulSoup(html_page.content, 'html.parser')
  images = []
  for img in soup.findAll('img'):
      images.append(img.get('data-img'))
  images = [i for i in images if i]

  # setting filename and image URL
  prod_type = df['product_type'][i]
  sku = df['sku'][i]
  filename = 'images/'+prod_type+'_'+sku+'.jpg'
  image_url = images[0]

  # calling urlretrieve function to get resource
  urllib.request.urlretrieve(image_url, filename)
